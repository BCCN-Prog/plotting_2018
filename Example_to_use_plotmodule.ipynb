# %%
import pandas as pd
import database as db
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from calendar import monthrange

import label_dict as ld
import plot_with_right_labels as plt_w
import query_plotting as qp

# %matplotlib inline

# %%
db.set_up_connection(db.db, 'db_weather', user='webscrapers', password='bCCnw3b')

# %%
qp.show_all_labels()
# Out:
# ['humidity', 'min temperature', 'snow depth', 'vapor pressure', 'mean temperature', 'max wind gust', 'cloud cover', 'sunshine duration', 'pressure', 'mean wind velocity', 'max temperature']

# %%
city = 'Berlin'
label = 'max temperature'
lis = []
for i in range(6):
    start = str(2013+i)+'05'
    end = str(2013+i)+'06'
    
    lis.append(qp.query_for_plot(start, end, label, city))

# %%
for i,l in enumerate(lis):
    plt_w.plotting(l, label)
